# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Load API Credentials
with open('/Users/JoseH/.secret/yelp_api.json') as f:   
    login = json.load(f)
# Instantiate YelpAPI Variable
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)

# %%
# set our API call parameters and filename before the first call
LOCATION = 'Washington DC,DC,20001'
TERM = 'pizza'

# %%
JSON_FILE = f"Data/results_in_progress_pizza_DC.json"

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:
    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    with open(JSON_FILE,'w') as f:
        json.dump([],f)  
        
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/results_in_progress_pizza_DC.json not found. Saving empty list to file.

# %%
#Getting lenght needed for Efficient Extraction
lenght_results = yelp_api.search_query(location=LOCATION,
                                term=TERM,
                              )
total = lenght_results['total']
print(f'Total Businesses: {total}')
results_per_page = len(lenght_results['businesses'])
print(f'Total Businesses per page: {results_per_page}')

# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((lenght_results['total'])/ results_per_page)
print(f'Total number of Pages Needed: {n_pages}')
# Out:
# Total Businesses: 788
# Total Businesses per page: 20
# Total number of Pages Needed: 40

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
    time.sleep(.2)
    ## Read in results in progress file and check the length
    with open(JSON_FILE, 'r') as f:
        previous_results = json.load(f)
    ## save number of results for to use as offset
    n_results = len(previous_results)
    ## use n_results as the OFFSET 
    results = yelp_api.search_query(location=LOCATION,
                                    term=TERM, 
                                    offset=n_results)
    
    ## append new results and save to file
    previous_results.extend(results['businesses'])
    
#     display(previous_results)
    with open(JSON_FILE,'w') as f:
        json.dump(previous_results,f)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
# load final results
final_df = pd.read_json(JSON_FILE)
display(final_df.head(), final_df.tail())
# Out:
#                        id                                             alias  \
# 0  2GWtmU5XZCes8LMisE2zVA                        wiseguy-pizza-washington-3
# 1  QSXp7oMGcmSYOupDHb-ZXg  kouzina-angelinas-pizzeria-shaw-dc-washington-10
# 2  ukk2Ko-J730EfQFqWFX0pQ                       andys-pizza-shaw-washington
# 3  g3mIdtLBk9eoHrFGUGnqYw                         bacio-pizzeria-washington
# 4  zV4lywalabn7CDRbUoRhMw                          pi-pizzeria-washington-3
#
#                                    name  \
# 0                         Wiseguy Pizza
# 1  Kouzina Angelinas Pizzeria - Shaw DC
# 2                   Andy's Pizza - Shaw
# 3                        Bacio Pizzeria
# 4                           Pi Pizzeria
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/tMwsFv...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/tZwyvC...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/smyHG6...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/VX_RXL...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/exCEqB...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/wiseguy-pizza-washing...          1207
# 1  https://www.yelp.com/biz/kouzina-angelinas-piz...           128
# 2  https://www.yelp.com/biz/andys-pizza-shaw-wash...           137
# 3  https://www.yelp.com/biz/bacio-pizzeria-washin...           314
# 4  https://www.yelp.com/biz/pi-pizzeria-washingto...          1831
#
#                                           categories  rating  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 2             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 3  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 4  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 38.8996423212243, 'longitude': -7...  [delivery, pickup]
# 1  {'latitude': 38.9167436222272, 'longitude': -7...  [delivery, pickup]
# 2  {'latitude': 38.917545996101545, 'longitude': ...  [delivery, pickup]
# 3    {'latitude': 38.91494, 'longitude': -77.011701}  [delivery, pickup]
# 4   {'latitude': 38.897154, 'longitude': -77.024709}  [delivery, pickup]
#
#   price                                           location         phone  \
# 0     $  {'address1': '300 Massachusetts Ave NW', 'addr...  +12024087800
# 1     $  {'address1': '725 Florida Ave NW', 'address2':...  +12025887448
# 2   NaN  {'address1': '2016 9th St NW', 'address2': Non...  +12025062043
# 3    $$  {'address1': '81 Seaton Pl NW', 'address2': ''...  +12022322246
# 4    $$  {'address1': '910 F St NW', 'address2': '', 'a...  +12023935484
#
#     display_phone     distance
# 0  (202) 408-7800  1160.153369
# 1  (202) 588-7448   869.419229
# 2  (202) 506-2043  1015.092289
# 3  (202) 232-2246   749.410591
# 4  (202) 393-5484  1555.491406
#                          id                                 alias  \
# 783  n5xPYURRXHNIoObqvPRuLA                 subway-washington-175
# 784  XGKMeelsF3yPbY-jIZxZRA              grand-central-washington
# 785  tw7Jj6-NxYBKK2h5NVklug  potbelly-sandwich-shop-washington-36
# 786  xy2BRUHFGnOlRLfzxtcnzw       jyoti-indian-cuisine-washington
# 787  tuqWIWbAIjylU4VIh7dCyw          firehook-bakery-washington-4
#
#                        name  \
# 783                  Subway
# 784           Grand Central
# 785  Potbelly Sandwich Shop
# 786    Jyoti Indian Cuisine
# 787         Firehook Bakery
#
#                                              image_url  is_closed  \
# 783  https://s3-media2.fl.yelpcdn.com/bphoto/g-NI58...      False
# 784  https://s3-media1.fl.yelpcdn.com/bphoto/iQ44GA...      False
# 785  https://s3-media1.fl.yelpcdn.com/bphoto/7x_h57...      False
# 786  https://s3-media2.fl.yelpcdn.com/bphoto/_4UiZt...      False
# 787  https://s3-media2.fl.yelpcdn.com/bphoto/-z5Lzv...      False
#
#                                                    url  review_count  \
# 783  https://www.yelp.com/biz/subway-washington-175...            12
# 784  https://www.yelp.com/biz/grand-central-washing...           213
# 785  https://www.yelp.com/biz/potbelly-sandwich-sho...            55
# 786  https://www.yelp.com/biz/jyoti-indian-cuisine-...           440
# 787  https://www.yelp.com/biz/firehook-bakery-washi...           305
#
#                                             categories  rating  \
# 783   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     2.0
# 784  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     3.0
# 785  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     3.5
# 786           [{'alias': 'indpak', 'title': 'Indian'}]     3.5
# 787  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     3.5
#
#                                            coordinates        transactions  \
# 783  {'latitude': 38.9362026306009, 'longitude': -7...  [pickup, delivery]
# 784  {'latitude': 38.92098621688569, 'longitude': -...          [delivery]
# 785  {'latitude': 38.9036068371077, 'longitude': -7...  [pickup, delivery]
# 786     {'latitude': 38.92138, 'longitude': -77.04192}  [pickup, delivery]
# 787  {'latitude': 38.9112702, 'longitude': -77.043817}          [delivery]
#
#     price                                           location         phone  \
# 783     $  {'address1': '3520 Connecticut Ave NW', 'addre...  +12022372424
# 784    $$  {'address1': '2447 18th St NW', 'address2': ''...  +12029861742
# 785     $  {'address1': '1900 L St NW', 'address2': '', '...  +12024780026
# 786    $$  {'address1': '2433 18th St NW', 'address2': ''...  +12025185892
# 787     $  {'address1': '1909 Q St NW', 'address2': '', '...  +12026847400
#
#       display_phone     distance
# 783  (202) 237-2424  4636.285135
# 784  (202) 986-1742  2489.071544
# 785  (202) 478-0026  2368.598603
# 786  (202) 518-5892  2454.555915
# 787  (202) 684-7400  2273.352500

# %%
final_df.shape
# Out:
# (788, 16)

# %%
# check for duplicate IDs
final_df.duplicated(subset='id').sum()
# Out:
# 5

# %%
#Delete five duplicated ids
final_df=final_df.drop_duplicates(subset='id')

# %%
final_df.shape
# Out:
# (783, 16)

# %%
# save the final results to a csv
final_df.to_csv('Data/final_results_pizza_DC.csv',index=False)
